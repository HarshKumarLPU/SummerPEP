# %%
def sum(a,b):
    print(a+b)
sum(4,5)
# Out:
# 9

# %%
rows = 5
for i in range(rows):
    for j in range(rows):
        print("*",end=" ")
    print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
rows = 5
for i in range(1, rows+1):
    for j in range(i):
        print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
def calc(a,b):
    cal = a*b+a
    print(cal)
calc(4,5)
# Out:
# 24
