# %%
#Create a Book clas with attributes title, author, price,. Add a method display_info() that print all details.

class Book:
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self.price = price

    def display_info(self):
        print("Title:", self.title)
        print("Author:", self.author)
        print("Price:", self.price)


b1 = Book("Python Programming", "Guido van Rossum", 599)

b1.display_info()

# %%
#Create a Student class with roll_no, name, marks. Add a method get_grade() that returns "A" if marks >= 90, "b" if marks >= 75, else "C".

class Student:
    def __init__(self, roll_no, name, marks):
        self.roll_no = roll_no
        self.name = name
        self.marks = marks

    def get_grade(self):
        if self.marks >= 90:
            return "A"
        elif self.marks >= 75:
            return "B"
        else:
            return "C"

s1 = Student(28, "Harsh", 81)
s2 = Student(29, "Harshit", 91)

print(s1.get_grade())
print(s2.get_grade())
# Out:
# B
# A

# %%
# Create a Car class. Print "Car Object Created " inside the constructor and "Car Object destroyed" inside the destructor. Creaete two objects and observe when destructor messages appear

class Car:
    def __init__(self):
        print("Car Object Created")

    def __del__(self):
        print("Car Object Destroyed")


c1 = Car()
c2 = Car()

del c1
del c2
# Out:
# Car Object Created
# Car Object Created
# Car Object Destroyed
# Car Object Destroyed

# %%
#Create a Rectangle class with length and width. Add the methods area() and perimeter()
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)


r1 = Rectangle(10, 5)

print("Area:", r1.area())
print("Perimeter:", r1.perimeter())
# Out:
# Area: 50
# Perimeter: 30

# %%
# Create an Employee class with name and salary. Add a method give_raise(percent) that updaes self.salary in place(no return, just modify and print new salary)

class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
z
    def give_raise(self, percent):
        self.salary = self.salary + (self.salary * percent / 100)
        print("Updated Salary:", self.salary)


e1 = Employee("Harsh", 50000)

e1.give_raise(10)
# Out:
# Updated Salary: 55000.0

# %%
# Create a library class that holds a list of Book objects from Q1. Add methods add_book(Book) and show_all_books().

# %%
# Create an Employee class with a private attribute __salary. Add a getter and setter -  the setter should reject negative salaries. Ad a method apply_raise(percent) that incereases salary using the setter internally 

class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.__salary = salary

    def get_salary(self):
        return self.__salary

    def set_salary(self,salary):
        if salary>= 0:
            self.__salary = salary
        else:
            print("Salary cannot be negative")

    def apply_raise(self, percent):
        new_salary = self.__salary + (self.__salary * percent / 100)
        self.set_salary(new_salary)
        print("Updated Salary:", self.__salary)

e1 = Employee("Harsh", 50000)

print("Current Salary:", e1.get_salary())

e1.set_salary(-1000)

e1.apply_raise(10)
# Out:
# Current Salary: 50000
# Salary cannot be negative
# Updated Salary: 55000.0
